# %% [markdown]
# # Caída libre
#
# Las ecuaciones de movimiento son:
#
# $$
# \ddot{z}=-g,
# $$
#
# $$
# \ddot{x}=0,
# $$
#
# donde $g=9.8m/s^2$.

# %%
from pylab import *
from scipy.integrate import *

# %%
from pylab import *
from scipy.integrate import *
def caida(t,x_dx):
    # x_dx = x,z,vx,vz
    g = 9.8
    dx , dz = x_dx[2] , x_dx[3]
    dvx , dvz = 0 , -g
    return array([dx,dz,dvx,dvz])

def suelo_newton(t0,f,ind_pos=1,ind_d_pos=3,error=1e-4):
    while abs(f(t0)[ind_pos]) > error:
        t0 = t0 - f(t0)[ind_pos]/f(t0)[ind_d_pos]
    return t0

# %%
ci = [0,1,0.5,0]
tf = 2
tray = solve_ivp(caida,(0,tf),ci,dense_output=True,atol=1e-8,rtol=1e-8)
t_suelo = suelo_newton(0.1,tray.sol)
t_suelo
# Out:
# 0.451754452322883

# %%
t = linspace(0,t_suelo,15)
plot(tray.sol(t)[0],tray.sol(t)[1])
#primer rebote
ci = tray.sol(t_suelo)
ci[3] = -ci[3]
tray = solve_ivp(caida,(0,tf),ci,dense_output=True,atol=1e-8,rtol=1e-8)
t_suelo = suelo_newton(1.1*t_suelo,tray.sol)
print(t_suelo)
t = linspace(0,t_suelo,15)
plot(tray.sol(t)[0],tray.sol(t)[1])
#segundo rebote
ci = tray.sol(t_suelo)
ci[3] = -ci[3]
tray = solve_ivp(caida,(0,tf),ci,dense_output=True,atol=1e-8,rtol=1e-8)
t_suelo = suelo_newton(1.1*t_suelo,tray.sol)
print(t_suelo)
t = linspace(0,t_suelo,15)
plot(tray.sol(t)[0],tray.sol(t)[1])

ylim([-0.1,1.1])
show()
# Out:
# 0.9035107933228146
# 0.9035102966677566

# %%
def pelota_rebotando(ec_mov,ci,ts=5):
    tray_x ,tray_z = [] , []
    tray = solve_ivp(ec_mov,(0,ts),ci,dense_output=True,atol=1e-8,rtol=1e-8)
    t_suelo = suelo_newton(0.1,tray.sol)
    tiempo = linspace(0,t_suelo)
    tray_x.append(tray.sol(tiempo)[0])
    tray_z.append(tray.sol(tiempo)[1])
    t_vuelo = 2*t_suelo
    for i in range(5): # cinco rebotes
        ci = tray.sol(t_suelo)
        ci[3] = -ci[3]
        tray = solve_ivp(ec_mov,(0,ts),ci,dense_output=True,atol=1e-8,rtol=1e-8)
        t_suelo = suelo_newton(0.6*t_vuelo,tray.sol)
        tiempo = linspace(0,t_suelo)
        tray_x.append(tray.sol(tiempo)[0])
        tray_z.append(tray.sol(tiempo)[1])
        t_vuelo = t_suelo
    # acomodar los en vectores de una dimension
    nn , mm = array(tray_x).shape , array(tray_z).shape
    tray_x = reshape(tray_x,(nn[0]*nn[1]))
    tray_z = reshape(tray_z,(mm[0]*mm[1]))
    return tray_x , tray_z

# %%
ci = [0,1,0.5,0]
x,z = pelota_rebotando(caida,ci)

# %%
plot(x,z)

# %%
def caida_con__friccion_y_viento(t,x,dx):
    #x_dx,x,z,vx,vz
    g,gam=9.8,0.3
    dx,dz=x_dx[2],x_dx[3]
    dvx,dvz=-gam*x_dx[2]-0.2,-g-gam*x_dx[3]
    return array([dx,dz,dvx,dvz])

# %%
ci=[0,1,0.5,0]
x,z=pelota_rebotando(caida_con__friccion_y_viento,ci)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [50], in <cell line: 2>()
#       1 ci=[0,1,0.5,0]
# ----> 2 x,z=pelota_rebotando(caida_con__friccion_y_viento,ci)
#
# Input In [40], in pelota_rebotando(ec_mov, ci, ts)
#       1 def pelota_rebotando(ec_mov,ci,ts=5):
#       2     tray_x ,tray_z = [] , []
# ----> 3     tray = solve_ivp(ec_mov,(0,ts),ci,dense_output=True,atol=1e-8,rtol=1e-8)
#       4     t_suelo = suelo_newton(0.1,tray.sol)
#       5     tiempo = linspace(0,t_suelo)
#
# File ~\anaconda3\lib\site-packages\scipy\integrate\_ivp\ivp.py:542, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     539 if method in METHODS:
#     540     method = METHODS[method]
# --> 542 solver = method(fun, t0, y0, tf, vectorized=vectorized, **options)
#     544 if t_eval is None:
#     545     ts = [t0]
#
# ...

# %%
plot
